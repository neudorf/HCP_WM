# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# !ls
# %cd /content/drive/Shareddrives/Impact\ Scholars\ \(Scholars\ External\ Drive\)/Project\ Files\ \(2025\)/Mnemosyne\'a\ Cat\ GROUP/Github/HCP_WM
# !ls
# Out:
# /content
# drive  sample_data
# /content/drive/Shareddrives/Impact Scholars (Scholars External Drive)/Project Files (2025)/Mnemosyne'a Cat GROUP/Github/HCP_WM
#  github_push.ipynb
# 'ISP_Functional Connectivity with Network Statistics_BODY'
# 'ISP_Functional Connectivity with Network Statistics_FACE'
# 'ISP_Functional Connectivity with Network Statistics_PLACES'
# 'ISP_Functional Connectivity with Network Statistics_TOOLS'
# 'ISP_Functional Connectivity with Network Statistics_WM'
# 'ISP_Functional Connectivity with Network Statistics_WM_2back'
#  LICENSE
#  README.md

# %%
# !git config --global user.name "neudorf"
# !git config --global user.email "12356878+neudorf@users.noreply.github.com"

# %%
# !git add --all
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   ISP_Functional Connectivity with Network Statistics_BODY
# 	new file:   ISP_Functional Connectivity with Network Statistics_FACE
# 	new file:   ISP_Functional Connectivity with Network Statistics_PLACES
# 	new file:   ISP_Functional Connectivity with Network Statistics_TOOLS
# 	new file:   ISP_Functional Connectivity with Network Statistics_WM
# 	new file:   ISP_Functional Connectivity with Network Statistics_WM_2back
# 	new file:   github_push.ipynb

# %%
commit_message = input("Git commit message")
command = f"git commit -m '{commit_message}'"
# !{command}
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2436519456.py in <cell line: 0>()
# ----> 1 commit_message = input("Git commit message")
#       2 command = f"git commit -m '{commit_message}'"
#       3 get_ipython().system('{command}')
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
# !git push origin main
# Out:
# Enumerating objects: 10, done.
# Counting objects: 100% (10/10), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 35.34 MiB | 7.22 MiB/s, done.
# Total 9 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/neudorf/HCP_WM.git
#    64550da..507287d  main -> main

# %% [markdown]
# You can install Python libraries using the `!pip install` command followed by the library name. For example, to install the `numpy` library, you would run:

# %%
# !pip install numpy

# %% [markdown]
# If you need to install a specific version of a library, you can specify it like this:

# %%
# !pip install pandas==1.3.5

# %% [markdown]
# You can also install multiple libraries at once:

# %%
# !pip install matplotlib seaborn scikit-learn

# %% [markdown]
# After installation, you can then import and use the library in your Python code.
